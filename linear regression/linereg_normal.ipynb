# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    Hours  Score
# 0    1.5     55
# 1    3.0     65
# 2    4.5     75
# 3    2.0     60
# 4    5.0     80

# %%
x = df.iloc[:,:-1] # features
y = df.iloc[:,-1]  # target


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=40)


model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

for i in range(len(x_test)):
    print("Actual Value   :", y_test.iloc[i])
    print("Predicted Value:", y_pred[i])
# Out:
# Actual Value   : 72
# Predicted Value: 71.1043383523759
# Actual Value   : 87
# Predicted Value: 88.5772550772411
# Actual Value   : 66
# Predicted Value: 66.11207643098585
# Actual Value   : 80
# Predicted Value: 77.34466575411348
# Actual Value   : 63
# Predicted Value: 61.743847249769544
# Actual Value   : 50
# Predicted Value: 52.38335614716319
# Actual Value   : 76
# Predicted Value: 76.09660027376596

# %%
plt.scatter(x, y, color='red', label='Actual Data')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.plot(x_test, y_pred, color='blue', linewidth=2, label='Predicted Line')
plt.legend()
plt.show()

# %%
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 2.5172774740702266

# %%
r_squared = model.score(x_test, y_test)
print(f'R-squared Score: {r_squared:.2f}')
# Out:
# R-squared Score: 0.98
